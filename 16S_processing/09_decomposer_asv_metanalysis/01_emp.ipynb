# %% [markdown]
# # Decomp community

# %%
# qiime imports
import qiime2
from qiime2 import Artifact, Metadata

# General Tool Imports
import numpy as np
import pandas as pd
import collections
from pickle import load, dump
from IPython.display import display
import warnings

# Plotting Imports
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns
from statannotations.Annotator import Annotator

import itertools
import scipy
import skbio

from skbio.stats import subsample_counts
from skbio import OrdinationResults
from statsmodels.sandbox.stats.multicomp import multipletests

# %matplotlib inline

# %%
# this is huge
samples = pd.read_csv('57196_57196_analysis_mapping.txt', sep ='\t',index_col=0)

# %%
samples.shape
# Out:
# (951, 416)

# %%
samples.groupby(['environmental_package'],dropna=False).agg({'center_project_name': 'count'})
# Out:
#                        center_project_name
# environmental_package
# host-associated                        368
# microbial mat/biofilm                    2
# misc environment                        15
# not applicable                          38
# plant-associated                        26
# sediment                               105
# soil                                   117
# wastewater/sludge                       16
# water                                   37

# %%
samples.groupby(['emp500_title'],dropna=False).agg({'center_project_name': 'count'})
# Out:
#                                               center_project_name
# emp500_title
# active layer soil                                              10
# animas watershed                                               10
# australian algae                                               40
# bioreactors for wastewater and anammox                         16
# biota oil (b2014.1 and b2016.1)                                 1
# captive aquatic mammal feces                                    4
# captive bird feces                                             15
# captive herp feces                                             15
# captive terrestrial mammal feces                               20
# centralia soil                                                  8
# chernobyl vole feces                                          112
# coal and coal-associated water                                 14
# costa rican leaf-cutter ant and bee material                   28
# english channel sediment                                        3
# english channel water                                           9
# fish gut contents                                              15
# franz josef land glacier soils and water                       11
# hyporheic sediment                                              4
# iberia and guatemala deep-sea sediments                        25
# livestock feces                                                 6
# marine oxygen minimum zone water                                8
# massachusetts salt marsh sediments                             16
# mexico microbial mats                                           3
# michigan forest lichen                                         12
# mongolia soils (nsf pire)                                       3
# namibia gravel plain gradient soils                             6
# not applicable                                                 39
# ocean sediments                                                19
# ocean sponges                                                  54
# oregon soils                                                   14
# palmyra algae                                                   8
# permafrost soil                                                 6
# peru and nepal alpine soils                                    13
# pitcher plant fluids                                           14
# postglacial pond sediment profiles                             20
# puhimau hawai'i volcanic soil                                  21
# rumen animals and bioreactor                                    9
# san diego seawater                                             20
# scleractinian corals                                           15
# shipworm tissue and wood                                       15
# singapore plant-associated soils                                7
# spanish hypersaline sandy soils                                12
# tree-associated soils                                           5
# west texas playa                                                7
# whale feces                                                    12

# %%
reads = pd.read_csv('emp_sample-frequency-detail.csv', index_col=0)

# %%
# get samples with >1000 reads
samples = samples[samples.index.isin(reads[reads['0']>1000].index)].copy()

# %%
# remove decomp samples
samples = samples.loc[~samples['project_name'].str.contains('decomp')].copy()

# %%
samples.shape
# Out:
# (724, 416)

# %%
emp_data = Artifact.load('171856_relative_frequency_table.qza').view(pd.DataFrame)

# %%
emp_data.shape
# Out:
# (928, 432075)

# %%
# remove unwanted samples
emp_data = emp_data[emp_data.index.isin(samples.index)]

# %%
# get pmi decomposer data
pmi_decom = pd.read_csv('../ASVs_repseq.txt',sep ='\t',index_col=0)

# %%
# get overlap between american gut and pmi asvs
overlap = list(set(pmi_decom.asv.tolist()).intersection(set(emp_data.columns.tolist())))

# %%
len(overlap)
# Out:
# 22

# %%
pmi_decom = pmi_decom.set_index('asv')

# %% [markdown]
# ### by environment

# %%
# mean abundance for each sample group
type_summary = emp_data[overlap].groupby(samples.environmental_package).mean()

# %%
# group by asv genus - add up abundance
type_summary.T.groupby(pmi_decom['genus']).sum().T
# Out:
# genus                  Acinetobacter  Bacteroides  Ignatzschineria  \
# environmental_package
# host-associated             0.004023     0.000002     0.000000e+00
# microbial mat/biofilm       0.000000     0.000000     0.000000e+00
# misc environment            0.015969     0.000000     0.000000e+00
# not applicable              0.006233     0.000000     0.000000e+00
# plant-associated            0.002935     0.000000     0.000000e+00
# sediment                    0.000122     0.000000     0.000000e+00
# soil                        0.000015     0.000000     7.831712e-07
# wastewater/sludge           0.000313     0.000000     0.000000e+00
# water                       0.000148     0.000000     0.000000e+00
#
# genus                   Oblitimonas  Peptoniphilus  Savagea    Vagococcus  \
# environmental_package
# host-associated        9.461010e-08       0.000007      0.0  1.474414e-05
# microbial mat/biofilm  0.000000e+00       0.000000      0.0  0.000000e+00
# misc environment       0.000000e+00       0.000000      0.0  0.000000e+00
# not applicable         0.000000e+00       0.000000      0.0  0.000000e+00
# plant-associated       0.000000e+00       0.000000      0.0  0.000000e+00
# sediment               0.000000e+00       0.000000      0.0  8.096584e-07
# soil                   0.000000e+00       0.000000      0.0  0.000000e+00
# wastewater/sludge      0.000000e+00       0.000000      0.0  2.517402e-05
# water                  0.000000e+00       0.000002      0.0  0.000000e+00
#
# genus                  Wohlfahrtiimonas
# environmental_package
# host-associated                     0.0
# microbial mat/biofilm               0.0
# misc environment                    0.0
# not applicable                      0.0
# plant-associated                    0.0
# sediment                            0.0
# soil                                0.0
# wastewater/sludge                   0.0
# water                               0.0

# %% [markdown]
# ### by project - might be more descriptive

# %%
# group samples by project  - get mean abundance
project_summary = emp_data[overlap].groupby(samples.emp500_title).mean()

# %%
# group asvs by genus - add up abundance
project_summary.T.groupby(pmi_decom['genus']).sum().T
# Out:
# genus                                         Acinetobacter  Bacteroides  \
# emp500_title
# active layer soil                                  0.000000     0.000000
# animas watershed                                   0.000413     0.000000
# australian algae                                   0.000004     0.000000
# bioreactors for wastewater and anammox             0.000313     0.000000
# biota oil (b2014.1 and b2016.1)                    0.000000     0.000000
# captive aquatic mammal feces                       0.000043     0.000000
# captive bird feces                                 0.004095     0.000000
# captive herp feces                                 0.017873     0.000000
# captive terrestrial mammal feces                   0.005866     0.000000
# centralia soil                                     0.000000     0.000000
# chernobyl vole feces                               0.000011     0.000002
# coal and coal-associated water                     0.017110     0.000000
# costa rican leaf-cutter ant and bee material       0.008792     0.000000
# english channel sediment                           0.000000     0.000000
# english channel water                              0.000013     0.000000
# fish gut contents                                  0.000453     0.000000
# franz josef land glacier soils and water           0.000000     0.000000
# hyporheic sediment                                 0.000306     0.000000
# iberia and guatemala deep-sea sediments            0.000241     0.000000
# livestock feces                                    0.014531     0.000093
# marine oxygen minimum zone water                   0.000000     0.000000
# massachusetts salt marsh sediments                 0.000067     0.000000
# mexico microbial mats                              0.000000     0.000000
# michigan forest lichen                             0.000000     0.000000
# mongolia soils (nsf pire)                          0.000237     0.000000
# namibia gravel plain gradient soils                0.000000     0.000000
# not applicable                                     0.006073     0.000000
# ocean sediments                                    0.000002     0.000000
# ocean sponges                                      0.011859     0.000000
# oregon soils                                       0.000012     0.000000
# palmyra algae                                      0.000512     0.000000
# permafrost soil                                    0.000000     0.000000
# peru and nepal alpine soils                        0.000000     0.000000
# pitcher plant fluids                               0.005450     0.000000
# postglacial pond sediment profiles                 0.000002     0.000000
# puhimau hawai'i volcanic soil                      0.000000     0.000000
# rumen animals and bioreactor                       0.001226     0.000000
# san diego seawater                                 0.000268     0.000000
# scleractinian corals                               0.002286     0.000000
# mongolia soils (nsf pire)                          0.000000      0.0
# namibia gravel plain gradient soils                0.000000      0.0
# not applicable                                     0.000000      0.0
# ocean sediments                                    0.000000      0.0
# ocean sponges                                      0.000000      0.0
# oregon soils                                       0.000000      0.0
# palmyra algae                                      0.000000      0.0
# permafrost soil                                    0.000000      0.0
# peru and nepal alpine soils                        0.000000      0.0
# pitcher plant fluids                               0.000000      0.0
# postglacial pond sediment profiles                 0.000000      0.0
# puhimau hawai'i volcanic soil                      0.000000      0.0
# rumen animals and bioreactor                       0.000000      0.0
# san diego seawater                                 0.000000      0.0
# scleractinian corals                               0.000000      0.0
# shipworm tissue and wood                           0.000000      0.0
# singapore plant-associated soils                   0.000000      0.0
# spanish hypersaline sandy soils                    0.000000      0.0
# tree-associated soils                              0.000000      0.0
# west texas playa                                   0.000000      0.0
# whale feces                                        0.000000      0.0
#
# genus                                           Vagococcus  Wohlfahrtiimonas
# emp500_title
# active layer soil                             0.000000e+00               0.0
# animas watershed                              0.000000e+00               0.0
# australian algae                              0.000000e+00               0.0
# bioreactors for wastewater and anammox        2.517402e-05               0.0
# biota oil (b2014.1 and b2016.1)               0.000000e+00               0.0
# captive aquatic mammal feces                  0.000000e+00               0.0
# captive bird feces                            1.564007e-05               0.0
# captive herp feces                            1.344267e-05               0.0
# captive terrestrial mammal feces              2.337323e-04               0.0
# centralia soil                                0.000000e+00               0.0
# chernobyl vole feces                          2.979816e-07               0.0
# coal and coal-associated water                0.000000e+00               0.0
# costa rican leaf-cutter ant and bee material  1.005647e-05               0.0
# english channel sediment                      0.000000e+00               0.0
# english channel water                         0.000000e+00               0.0
# fish gut contents                             0.000000e+00               0.0
# franz josef land glacier soils and water      0.000000e+00               0.0
# hyporheic sediment                            0.000000e+00               0.0
# iberia and guatemala deep-sea sediments       0.000000e+00               0.0
# livestock feces                               0.000000e+00               0.0
# marine oxygen minimum zone water              0.000000e+00               0.0
# massachusetts salt marsh sediments            0.000000e+00               0.0
# mexico microbial mats                         0.000000e+00               0.0
# michigan forest lichen                        0.000000e+00               0.0
# mongolia soils (nsf pire)                     0.000000e+00               0.0
# namibia gravel plain gradient soils           0.000000e+00               0.0
# not applicable                                0.000000e+00               0.0
# ocean sediments                               4.474428e-06               0.0
# ocean sponges                                 0.000000e+00               0.0
# oregon soils                                  0.000000e+00               0.0
# palmyra algae                                 0.000000e+00               0.0
# permafrost soil                               0.000000e+00               0.0
# peru and nepal alpine soils                   0.000000e+00               0.0
# pitcher plant fluids                          0.000000e+00               0.0
# postglacial pond sediment profiles            0.000000e+00               0.0
# puhimau hawai'i volcanic soil                 0.000000e+00               0.0
# rumen animals and bioreactor                  0.000000e+00               0.0
# san diego seawater                            0.000000e+00               0.0
# scleractinian corals                          0.000000e+00               0.0
# shipworm tissue and wood                      0.000000e+00               0.0
# singapore plant-associated soils              0.000000e+00               0.0
# spanish hypersaline sandy soils               0.000000e+00               0.0
# tree-associated soils                         0.000000e+00               0.0
# west texas playa                              0.000000e+00               0.0
# whale feces                                   0.000000e+00               0.0

# %% [markdown]
# ### how many samples are they found in?

# %%
# of samples each asv is found in
pd.concat([pmi_decom.loc[pmi_decom.index.isin(overlap)][['genus','species']],
           emp_data[overlap].groupby(samples['emp500_title']).apply(lambda x: (x>0).sum()).T],axis=1).T.to_csv('/Users/victorianieciecki/Desktop/alsdjf.csv',sep='\t')

# %% [markdown]
# age - average count across the group
# decomposer - sum across the genus
