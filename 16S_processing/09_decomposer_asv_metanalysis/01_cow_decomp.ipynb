# %% [markdown]
# # Decomp community

# %%
# qiime imports
import qiime2
from qiime2 import Artifact, Metadata

# General Tool Imports
import numpy as np
import pandas as pd
import collections
from pickle import load, dump
from IPython.display import display
import warnings

# Plotting Imports
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import seaborn as sns
# from statannotations.Annotator import Annotator

import itertools
import scipy
import skbio

from skbio.stats import subsample_counts
from skbio import OrdinationResults
from statsmodels.sandbox.stats.multicomp import multipletests

# %matplotlib inline

# %%
samples = Metadata.load('SraRunTable.txt').to_dataframe()

# %%
decay = samples.loc[samples['decomp_stage']=='active_decay'].copy()

# %%
data = Artifact.load('table_r1.qza').view(pd.DataFrame)

# %%
decay['reads'] = data.sum(axis=1)

# %%
decay[['reads']]
# Out:
#                 reads
# sample-id
# 0COWd025.30   36379.0
# 0COWd024.30    3423.0
# 0COWd023.30   76118.0
# 0COWd027.30   58195.0
# 0COWd026.30   60343.0
# 0COWd028.30   52440.0
# 0COWd029.30   40682.0
# 0COWd030.30   86762.0
# 0COWd031.30   58603.0
# 0COWd032.30    7857.0
# 0COWd033.30   66662.0
# 0COWd034.30   44639.0
# 0COWd035.30    1031.0
# 0COWd036.30   54615.0
# 0COWd037.30   35869.0
# 0COWd006.30   61026.0
# 0COWd002.30   75298.0
# 0COWd041.20   74628.0
# 0COWd002.20  139578.0
# 0COWd006.20   86638.0
# 0COWd030.20   68615.0
# 0COWd029.20   69958.0
# 0COWd024.20  127639.0
# 0COWd023.20   67856.0
# 0COWd028.20   61847.0
# 0COWd027.20   70297.0
# 0COWd026.20   61674.0
# 0COWd025.20   69515.0
# 0COWd039.30   84681.0
# 0COWd038.30   59750.0
# 0COWd041.30   55843.0
# 0COWd040.30   98701.0
# 0COWd035.20   70910.0
# 0COWd036.20   67295.0
# 0COWd037.20   62770.0
# 0COWd038.20   79219.0
# 0COWd031.20   41415.0
# 0COWd032.20  124244.0
# 0COWd033.20   75400.0
# 0COWd034.20   60931.0
# 0COWd039.20   75077.0
# 0COWd040.20   75626.0

# %% [markdown]
# I'm just not at all sure what the .20 vs .30 means and which we should use...

# %%
# get samples with >1000 reads
decay = decay.loc[decay['reads']>1000].copy()

# %%
decay.groupby(['decomp_stage'], dropna=False).count()['Run'].to_frame()
# Out:
#               Run
# decomp_stage
# active_decay   42

# %%
# only get data for samples > 1000 reads
data = data[data.index.isin(decay.index)]

# %%
# remove zero columns
data = data.loc[:, (data.sum(axis=0) != 0)]

# %%
# get seqs
seqs = Artifact.load('rep_seqs_r1.qza').view(qiime2.Metadata).to_dataframe()

# %%
seqs.shape
# Out:
# (6544, 1)

# %%
# remove seqs with no reads
seqs = seqs.loc[seqs.index.isin(data.columns)]

# %%
seqs.shape
# Out:
# (2426, 1)

# %% [markdown]
# ### Import Decomposers

# %%
pmi_decom = pd.read_csv('../ASVs_repseq.txt',sep ='\t',index_col=0)

# %%
pmi_decom.groupby('genus').count()['150_asv'].to_frame()
# Out:
#                   150_asv
# genus
# Acinetobacter           5
# Bacteroides             9
# Ignatzschineria         4
# Oblitimonas             1
# Peptoniphilus           5
# Savagea                 3
# Vagococcus              5
# Wohlfahrtiimonas        3

# %%
# pmi decomposers found in cow data
cow_decomp = list(set(pmi_decom.index.tolist()).intersection(set(seqs.index.tolist())))

# %%
print("{} ASVs were found in cow data".format(len(cow_decomp)))
# Out:
# 26 ASVs were found in cow data

# %% [markdown]
# ## Collapse reads data table on 150 bp ASVs
# sum reads of asvs with same 150 bp sequence

# %%
# make ra table
ra = data.apply(lambda x: x / x.sum(), axis=1)

# %%
## average of each asv across all the active decomp samples
ra_cow = ra[cow_decomp].groupby(decay['decomp_stage']).mean()

# %%
## averages summed by genus
ra_cow.T.groupby(pmi_decom['genus']).sum()
# Out:
# decomp_stage      active_decay
# genus
# Acinetobacter         0.000008
# Bacteroides           0.008243
# Ignatzschineria       0.036005
# Oblitimonas           0.000031
# Peptoniphilus         0.000620
# Savagea               0.047552
# Vagococcus            0.001299
# Wohlfahrtiimonas      0.001433

# %% [markdown]
# ### how many samples are these decomposer asvs found in?

# %%
# of samples each asv is found in
pd.concat([pmi_decom.loc[pmi_decom.index.isin(cow_decomp)][['genus','species']],
           ra[cow_decomp].groupby(decay['decomp_stage']).apply(lambda x: (x>0).sum()).T],axis=1)
# Out:
#                                              genus  \
# 9acc238746a1f2aa7745a0b5720c4eac     Acinetobacter
# 6e8986f8088b452f964e7968bb8bca87     Acinetobacter
# 174b6959ecfedfee56c9daf6ffa45d2b           Savagea
# 7567be5b5c8b7a16dbb1a84f6b46d965           Savagea
# 8a8c381201ca5a905366fdf242c076db           Savagea
# 837e0d796b199b8c9b462d97ad3c5599       Oblitimonas
# b08c80963ce4a0df0518836d2da209ce        Vagococcus
# 8e87132c368c4f56dd114b1cab5f59a6        Vagococcus
# cceb21819b328ad472f3e5fa20b3cbd9        Vagococcus
# 92460066faddd83314cbc2348bf4fd29        Vagococcus
# 48113de4cb4849e5d543cbb0579c847e        Vagococcus
# 3f3903c2eb9f2f31e38ef634cbf5e453   Ignatzschineria
# 3b97413ffc0ea1b441f7bd9daae2e3ee   Ignatzschineria
# 8c0327179680bf87ba7562ee11deadbc   Ignatzschineria
# 07db6c743fdc4cdcc722d93f60cc7d7d   Ignatzschineria
# a57f137f301b05aace3963acf6e4c543  Wohlfahrtiimonas
# 91c65f3ef3bb819833863e2270c6e51a     Peptoniphilus
# 74c2f872eb9d449e534c01528e6a08b4     Peptoniphilus
# 10a00f258ac2cb87f3a3b803b0f42d4d     Peptoniphilus
# 920843428e906d7a8d33fddaf15f0b4a       Bacteroides
# 7ac5b2da79a1d4157add556d0b1cc2d0       Bacteroides
# 6f3054e2de231807b48510fd6a13b71f       Bacteroides
# d5fea27ea9135ffa5d671abd36462cbb       Bacteroides
# 7763fab156a2af71cf16deb2dea2afee       Bacteroides
# 3cf3e0098557c10317cc8aea44f7054e       Bacteroides
# 9faf1968e6338160ee3009dae65e1531       Bacteroides
#
#                                                            species  \
# 9acc238746a1f2aa7745a0b5720c4eac                               NaN
# 6e8986f8088b452f964e7968bb8bca87                               NaN
# 174b6959ecfedfee56c9daf6ffa45d2b              uncultured bacterium
# 7567be5b5c8b7a16dbb1a84f6b46d965              uncultured bacterium
# 8a8c381201ca5a905366fdf242c076db              uncultured bacterium
# 837e0d796b199b8c9b462d97ad3c5599           Oblitimonas alkaliphila
# b08c80963ce4a0df0518836d2da209ce                               NaN
# 8e87132c368c4f56dd114b1cab5f59a6                               NaN
# cceb21819b328ad472f3e5fa20b3cbd9                               NaN
# 92460066faddd83314cbc2348bf4fd29                               NaN
# 48113de4cb4849e5d543cbb0579c847e                               NaN
# 3f3903c2eb9f2f31e38ef634cbf5e453                               NaN
# 3b97413ffc0ea1b441f7bd9daae2e3ee                               NaN
# 8c0327179680bf87ba7562ee11deadbc                               NaN
# 07db6c743fdc4cdcc722d93f60cc7d7d            Ignatzschineria larvae
# a57f137f301b05aace3963acf6e4c543  Wohlfahrtiimonas chitiniclastica
# 91c65f3ef3bb819833863e2270c6e51a                               NaN
# 74c2f872eb9d449e534c01528e6a08b4        Peptoniphilus stercorisuis
# 10a00f258ac2cb87f3a3b803b0f42d4d       swine manure bacterium 37-5
# 920843428e906d7a8d33fddaf15f0b4a                               NaN
# 7ac5b2da79a1d4157add556d0b1cc2d0                               NaN
# 6f3054e2de231807b48510fd6a13b71f                               NaN
# d5fea27ea9135ffa5d671abd36462cbb                               NaN
# 7763fab156a2af71cf16deb2dea2afee             Bacteroides coprosuis
# 3cf3e0098557c10317cc8aea44f7054e        uncultured Bacteroides sp.
# 9faf1968e6338160ee3009dae65e1531             uncultured prokaryote
#
#                                   active_decay
# 9acc238746a1f2aa7745a0b5720c4eac             1
# 6e8986f8088b452f964e7968bb8bca87             3
# 174b6959ecfedfee56c9daf6ffa45d2b            36
# 7567be5b5c8b7a16dbb1a84f6b46d965             2
# 8a8c381201ca5a905366fdf242c076db             2
# 837e0d796b199b8c9b462d97ad3c5599             6
# b08c80963ce4a0df0518836d2da209ce             1
# 8e87132c368c4f56dd114b1cab5f59a6            15
# cceb21819b328ad472f3e5fa20b3cbd9             9
# 92460066faddd83314cbc2348bf4fd29            12
# 48113de4cb4849e5d543cbb0579c847e             9
# 3f3903c2eb9f2f31e38ef634cbf5e453            25
# 3b97413ffc0ea1b441f7bd9daae2e3ee             4
# 8c0327179680bf87ba7562ee11deadbc             4
# 07db6c743fdc4cdcc722d93f60cc7d7d            22
# a57f137f301b05aace3963acf6e4c543            14
# 91c65f3ef3bb819833863e2270c6e51a            13
# 74c2f872eb9d449e534c01528e6a08b4             8
# 10a00f258ac2cb87f3a3b803b0f42d4d            15
# 920843428e906d7a8d33fddaf15f0b4a            18
# 7ac5b2da79a1d4157add556d0b1cc2d0             4
# 6f3054e2de231807b48510fd6a13b71f             2
# d5fea27ea9135ffa5d671abd36462cbb             8
# 7763fab156a2af71cf16deb2dea2afee             7
# 3cf3e0098557c10317cc8aea44f7054e             2
# 9faf1968e6338160ee3009dae65e1531             1

# %%
## percent of samples each ASV is found in
pd.concat([pmi_decom.loc[pmi_decom.index.isin(cow_decomp)][['genus','species']], (data[cow_decomp].groupby(decay['decomp_stage']).apply(
    lambda x: (x>0).sum()).T)/(data[cow_decomp].groupby(decay['decomp_stage']).count().T)*100], axis=1)
# Out:
#                                              genus  \
# 9acc238746a1f2aa7745a0b5720c4eac     Acinetobacter
# 6e8986f8088b452f964e7968bb8bca87     Acinetobacter
# 174b6959ecfedfee56c9daf6ffa45d2b           Savagea
# 7567be5b5c8b7a16dbb1a84f6b46d965           Savagea
# 8a8c381201ca5a905366fdf242c076db           Savagea
# 837e0d796b199b8c9b462d97ad3c5599       Oblitimonas
# b08c80963ce4a0df0518836d2da209ce        Vagococcus
# 8e87132c368c4f56dd114b1cab5f59a6        Vagococcus
# cceb21819b328ad472f3e5fa20b3cbd9        Vagococcus
# 92460066faddd83314cbc2348bf4fd29        Vagococcus
# 48113de4cb4849e5d543cbb0579c847e        Vagococcus
# 3f3903c2eb9f2f31e38ef634cbf5e453   Ignatzschineria
# 3b97413ffc0ea1b441f7bd9daae2e3ee   Ignatzschineria
# 8c0327179680bf87ba7562ee11deadbc   Ignatzschineria
# 07db6c743fdc4cdcc722d93f60cc7d7d   Ignatzschineria
# a57f137f301b05aace3963acf6e4c543  Wohlfahrtiimonas
# 91c65f3ef3bb819833863e2270c6e51a     Peptoniphilus
# 74c2f872eb9d449e534c01528e6a08b4     Peptoniphilus
# 10a00f258ac2cb87f3a3b803b0f42d4d     Peptoniphilus
# 920843428e906d7a8d33fddaf15f0b4a       Bacteroides
# 7ac5b2da79a1d4157add556d0b1cc2d0       Bacteroides
# 6f3054e2de231807b48510fd6a13b71f       Bacteroides
# d5fea27ea9135ffa5d671abd36462cbb       Bacteroides
# 7763fab156a2af71cf16deb2dea2afee       Bacteroides
# 3cf3e0098557c10317cc8aea44f7054e       Bacteroides
# 9faf1968e6338160ee3009dae65e1531       Bacteroides
#
#                                                            species  \
# 9acc238746a1f2aa7745a0b5720c4eac                               NaN
# 6e8986f8088b452f964e7968bb8bca87                               NaN
# 174b6959ecfedfee56c9daf6ffa45d2b              uncultured bacterium
# 7567be5b5c8b7a16dbb1a84f6b46d965              uncultured bacterium
# 8a8c381201ca5a905366fdf242c076db              uncultured bacterium
# 837e0d796b199b8c9b462d97ad3c5599           Oblitimonas alkaliphila
# b08c80963ce4a0df0518836d2da209ce                               NaN
# 8e87132c368c4f56dd114b1cab5f59a6                               NaN
# cceb21819b328ad472f3e5fa20b3cbd9                               NaN
# 92460066faddd83314cbc2348bf4fd29                               NaN
# 48113de4cb4849e5d543cbb0579c847e                               NaN
# 3f3903c2eb9f2f31e38ef634cbf5e453                               NaN
# 3b97413ffc0ea1b441f7bd9daae2e3ee                               NaN
# 8c0327179680bf87ba7562ee11deadbc                               NaN
# 07db6c743fdc4cdcc722d93f60cc7d7d            Ignatzschineria larvae
# a57f137f301b05aace3963acf6e4c543  Wohlfahrtiimonas chitiniclastica
# 91c65f3ef3bb819833863e2270c6e51a                               NaN
# 74c2f872eb9d449e534c01528e6a08b4        Peptoniphilus stercorisuis
# 10a00f258ac2cb87f3a3b803b0f42d4d       swine manure bacterium 37-5
# 920843428e906d7a8d33fddaf15f0b4a                               NaN
# 7ac5b2da79a1d4157add556d0b1cc2d0                               NaN
# 6f3054e2de231807b48510fd6a13b71f                               NaN
# d5fea27ea9135ffa5d671abd36462cbb                               NaN
# 7763fab156a2af71cf16deb2dea2afee             Bacteroides coprosuis
# 3cf3e0098557c10317cc8aea44f7054e        uncultured Bacteroides sp.
# 9faf1968e6338160ee3009dae65e1531             uncultured prokaryote
#
#                                   active_decay
# 9acc238746a1f2aa7745a0b5720c4eac      2.380952
# 6e8986f8088b452f964e7968bb8bca87      7.142857
# 174b6959ecfedfee56c9daf6ffa45d2b     85.714286
# 7567be5b5c8b7a16dbb1a84f6b46d965      4.761905
# 8a8c381201ca5a905366fdf242c076db      4.761905
# 837e0d796b199b8c9b462d97ad3c5599     14.285714
# b08c80963ce4a0df0518836d2da209ce      2.380952
# 8e87132c368c4f56dd114b1cab5f59a6     35.714286
# cceb21819b328ad472f3e5fa20b3cbd9     21.428571
# 92460066faddd83314cbc2348bf4fd29     28.571429
# 48113de4cb4849e5d543cbb0579c847e     21.428571
# 3f3903c2eb9f2f31e38ef634cbf5e453     59.523810
# 3b97413ffc0ea1b441f7bd9daae2e3ee      9.523810
# 8c0327179680bf87ba7562ee11deadbc      9.523810
# 07db6c743fdc4cdcc722d93f60cc7d7d     52.380952
# a57f137f301b05aace3963acf6e4c543     33.333333
# 91c65f3ef3bb819833863e2270c6e51a     30.952381
# 74c2f872eb9d449e534c01528e6a08b4     19.047619
# 10a00f258ac2cb87f3a3b803b0f42d4d     35.714286
# 920843428e906d7a8d33fddaf15f0b4a     42.857143
# 7ac5b2da79a1d4157add556d0b1cc2d0      9.523810
# 6f3054e2de231807b48510fd6a13b71f      4.761905
# d5fea27ea9135ffa5d671abd36462cbb     19.047619
# 7763fab156a2af71cf16deb2dea2afee     16.666667
# 3cf3e0098557c10317cc8aea44f7054e      4.761905
# 9faf1968e6338160ee3009dae65e1531      2.380952

# %% [markdown]
# ### look for other Wohlfahrtiimonas ASVs

# %%
taxa = Artifact.load('taxonomy_cow.qza').view(pd.DataFrame)

# %%
taxa
# Out:
#                                                                               Taxon  \
# Feature ID
# 1ee2e27913ab9da1f90335edc08cdd41  d__Bacteria; p__Proteobacteria; c__Gammaproteo...
# a4e3c4670582850046c5b8861bb2b55d  d__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 31ebb433ebf0b3e83259d826875b4438  d__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 491d5271c1aae8cf1c7838972148c36f  d__Bacteria; p__Firmicutes; c__Bacilli; o__Bac...
# 3e45cb330ef8321eb9c6da765103f82e  d__Bacteria; p__Bacteroidota; c__Bacteroidia; ...
# ...                                                                             ...
# 272fd5bb7d45eea7228a18bcb514bcc8  d__Bacteria; p__Actinobacteriota; c__Actinobac...
# c79f4725cd4d3aee747768baec21ab77  d__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 1986030e3c5cd5df6d869054bc96e536  d__Bacteria; p__Proteobacteria; c__Gammaproteo...
# 3f12521ca90170cca7506c92e8ad8979  d__Bacteria; p__Firmicutes; c__Clostridia; o__...
# 6bf09a8ed5a3c62e81f7e8df1c97c1ab  d__Archaea; p__Crenarchaeota; c__Nitrososphaer...
#
#                                           Confidence
# Feature ID
# 1ee2e27913ab9da1f90335edc08cdd41   0.999993574820448
# a4e3c4670582850046c5b8861bb2b55d  0.9949952317699843
# 31ebb433ebf0b3e83259d826875b4438  0.9999999504926806
# 491d5271c1aae8cf1c7838972148c36f  0.9405262599343626
# 3e45cb330ef8321eb9c6da765103f82e  0.9997986751531613
# ...                                              ...
# 272fd5bb7d45eea7228a18bcb514bcc8   0.991352683918789
# c79f4725cd4d3aee747768baec21ab77  0.9893301558754087
# 1986030e3c5cd5df6d869054bc96e536  0.8804667917601529
# 3f12521ca90170cca7506c92e8ad8979  0.7758298232771055
# 6bf09a8ed5a3c62e81f7e8df1c97c1ab  0.9999995979162611
#
# [6544 rows x 2 columns]

# %%
taxa['asv'] = seqs['Sequence']

# %%
taxa.loc[taxa.Taxon.str.contains('wohlf', case=False)].Taxon.values
# Out:
# array(['d__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Wohlfahrtiimonas; s__Wohlfahrtiimonas_chitiniclastica',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Koukoulia; s__Koukoulia_aurantiaca',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Wohlfahrtiimonas; s__Wohlfahrtiimonas_chitiniclastica',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Koukoulia; s__Koukoulia_aurantiaca',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent'],
#       dtype=object)

# %%
#anything with Wohl in name
wohl = taxa.loc[taxa.Taxon.str.contains('Wohlf', case=False)].copy()

# %%
wohl.Taxon.values
# Out:
# array(['d__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Wohlfahrtiimonas; s__Wohlfahrtiimonas_chitiniclastica',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Koukoulia; s__Koukoulia_aurantiaca',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Wohlfahrtiimonas; s__Wohlfahrtiimonas_chitiniclastica',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__Ignatzschineria_sp.',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Koukoulia; s__Koukoulia_aurantiaca',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Ignatzschineria; s__swine_effluent'],
#       dtype=object)

# %%
# remove anything that has a g__Ignatzschineria classification
wohl = wohl.loc[~wohl.Taxon.str.contains('g__Ignat')]

# %%
wohl.Taxon.values
# Out:
# array(['d__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Wohlfahrtiimonas; s__Wohlfahrtiimonas_chitiniclastica',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Koukoulia; s__Koukoulia_aurantiaca',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Wohlfahrtiimonas; s__Wohlfahrtiimonas_chitiniclastica',
#        'd__Bacteria; p__Proteobacteria; c__Gammaproteobacteria; o__Cardiobacteriales; f__Wohlfahrtiimonadaceae; g__Koukoulia; s__Koukoulia_aurantiaca'],
#       dtype=object)

# %%
# all wohl in dataset
cow_wohl = list(set(data.columns.tolist()).intersection(set(wohl.index)))

# %%
# get new wohl asvs - remove those found in pmi decomposers
other_wohl = list(set(cow_wohl).difference(set(pmi_decom.index)))

# %%
other_wohl
# Out:
# ['2852607842f0cae1ef1c11dc0de80c3d',
#  '6a8bf8de9e5fd208b17866cb3323520a',
#  'd2fe79722e176a4eea6e323ee5dc2358',
#  '67056d02c33331ac5e790f715d5dfdee']

# %%
pmi_decom.loc[pmi_decom.index.isin(other_wohl)]
# Out:
# Empty DataFrame
# Columns: [taxonomy, 150_asv, 100_bp, kingdom, phylum, class, order, family, genus, species]
# Index: []

# %%
data[other_wohl].sum()
# Out:
# 2852607842f0cae1ef1c11dc0de80c3d      28.0
# 6a8bf8de9e5fd208b17866cb3323520a    3961.0
# d2fe79722e176a4eea6e323ee5dc2358     254.0
# 67056d02c33331ac5e790f715d5dfdee      82.0
# dtype: float64

# %%
## average of each asv across all the active decomp samples
ra_wohl = ra[other_wohl].groupby(decay['decomp_stage']).mean()

# %%
ra_wohl.sum(axis=1).to_frame(name='Wohlfahrtiimonadaceae')
# Out:
#               Wohlfahrtiimonadaceae
# decomp_stage
# active_decay               0.001488

# %%
len(seqs['Sequence'][0])
# Out:
# 150
